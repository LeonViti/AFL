# %% [markdown]
# # Libraries

# %%
library(fitzRoy)
library(dplyr)
library(jsonlite)
library(lubridate)
library(purrr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Warning message in system("timedatectl", intern = TRUE):
# “running command 'timedatectl' had status 1”
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
#
# Attaching package: ‘purrr’
#
#
# The following object is masked from ‘package:jsonlite’:
#
#     flatten

# %% [markdown]
# # Functions

# %%
preprocess_fixture <- function(fixture) {
    # create new column for each state. 
    fixture_clean <- fixture %>% mutate(region = case_when(
        venue %in% c('Adelaide Hills', 'Adelaide Oval', 'Norwood Oval', 'Football Park') ~ "SA",
        venue %in% c('M.C.G.', 'Docklands', 'Eureka Stadium', 'Kardinia Park', 'Marvel Stadium', 
                     'GMHBA Stadium', 'Mars Stadium') ~ "VIC",
        venue %in% c('Carrara', 'Gabba', "Cazaly's Stadium", "Riverway Stadium") ~ "QLD",
        venue %in% c('S.C.G.', 'Sydney Showground', 'Stadium Australia', 'Blacktown') ~ "NSW",
        venue %in% c('Marrara Oval', 'Traeger Park') ~ 'NT',
        venue %in% c('Bellerive Oval', 'York Park', 'University of Tasmania Stadium') ~ "TAS",
        venue %in% c('Manuka Oval', 'UNSW Canberra Oval') ~ 'ACT',
        venue %in% c('Perth Stadium', 'Optus Stadium', 'Subiaco') ~ 'WA',
        venue %in% c('Jiangwan Stadium', 'Adelaide Arena at Jiangwan Stadium') ~ 'CHN',
        TRUE ~ NA_character_  # set NA for all other observations
    ))
    
    
    fixture_clean$date <- as.Date(fixture_clean$localtime)
    fixture_clean$time <- format(ymd_hms(fixture_clean$localtime), "%H:%M:%S")
    fixture_clean$home_win <- ifelse(fixture_clean$hscore > fixture_clean$ascore, 1, 0) 
    fixture_clean$hdiff <- fixture_clean$hscore - fixture_clean$ascore
    
    # select specific rows
    fixture_clean <- select(fixture_clean, year, round, date, time, region, venue, hteam, ateam, hscore, ascore, 
                            is_grand_final, is_final, home_win, hdiff)
    
    return(fixture_clean)
}


# function to check if a column contains NA values.
check_na_column <- function(df, col_name) {
    return(sum(is.na(df[[col_name]])))
}

# %% [markdown]
# # Data Cleaning
#
# ## Fixture Data

# %% [markdown]
# Start with the cruncher data as it provides a good baseline to work with.

# %%
# cruncher gives some good clean baseline data to work with  
cruncher <- fromJSON("https://thecruncherau.vercel.app/afl/data.json")

# %% [markdown]
# Create a new column to represent a home win.

# %%
fixture_12 <- fetch_fixture_squiggle(2012)
fixture_13 <- fetch_fixture_squiggle(2013)
fixture_14 <- fetch_fixture_squiggle(2014)
fixture_15 <- fetch_fixture_squiggle(2015)
fixture_16 <- fetch_fixture_squiggle(2016)
fixture_17 <- fetch_fixture_squiggle(2017)
fixture_18 <- fetch_fixture_squiggle(2018)
fixture_19 <- fetch_fixture_squiggle(2019)
fixture_20 <- fetch_fixture_squiggle(2020)
fixture_21 <- fetch_fixture_squiggle(2021)
fixture_22 <- fetch_fixture_squiggle(2022)
fixture_23 <- fetch_fixture_squiggle(2023)

fixture = rbind(fixture_12, fixture_13, fixture_14, fixture_15, fixture_16, fixture_17, 
                fixture_18, fixture_19, fixture_20, fixture_21, fixture_22, fixture_23)
# Out:
# ℹ No round specified - returning results for all rounds in 2012
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2012
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2012 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2013
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2013
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2013 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2014
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2014
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2014 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2015
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2015
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2015 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2016
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2016
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2016 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2017
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2017
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2017 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2018
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2018
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2018 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2019
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2019
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2019 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2020
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2020
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2020 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2021
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2021
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2021 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2022
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2022
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2022 ... done
#
#
#
# ℹ No round specified - returning results for all rounds in 2023
#
# ℹ Getting data from https://api.squiggle.com.au/?q=games;year=2023
#
# ✔ Getting data from https://api.squiggle.com.au/?q=games;year=2023 ... done

# %% [markdown]
# Combine all the rows of each of the dataframes to get data for years 2017 to 2023.

# %% [markdown]
# Local time used instead of date as it has the time based on the location of the game. Will split local time into two variables, date and time. Will using venue will create a column for State/region.

# %%
colnames(fixture)
# Out:
#  [1] "venue"          "hbehinds"       "ascore"         "hgoals"
#  [5] "year"           "round"          "complete"       "tz"
#  [9] "ateamid"        "unixtime"       "ateam"          "date"
# [13] "is_grand_final" "is_final"       "winnerteamid"   "agoals"
# [17] "updated"        "roundname"      "hteamid"        "winner"
# [21] "hteam"          "id"             "timestr"        "abehinds"
# [25] "localtime"      "hscore"

# %%
head(fixture)
# Out:
#   venue             hbehinds ascore hgoals year round complete tz     ateamid
# 1 Subiaco            9       101    16     2012 1     100      +11:00  7
# 2 Carrara            8       137    10     2012 1     100      +11:00  1
# 3 Stadium Australia  7       100     5     2012 1     100      +11:00 16
# 4 M.C.G.            17       115    20     2012 1     100      +11:00  4
# 5 M.C.G.            12       119    11     2012 1     100      +11:00  2
# 6 Docklands         12       104    15     2012 1     100      +11:00  5
#   unixtime   ⋯ updated             roundname hteamid winner
# 1 1333183500 ⋯ 2018-06-26 12:17:05 Round 1    6      Fremantle
# 2 1333172700 ⋯ 2018-06-26 12:17:05 Round 1    8      Adelaide
# 3 1332577200 ⋯ 2018-06-26 12:17:05 Round 1    9      Sydney
# 4 1333097400 ⋯ 2018-06-26 12:17:05 Round 1   10      Hawthorn
# 5 1333161900 ⋯ 2018-06-26 12:17:05 Round 1   11      Brisbane Lions
# 6 1333183500 ⋯ 2018-06-26 12:17:05 Round 1   12      Essendon
#   hteam                  id   timestr   abehinds localtime           hscore
# 1 Fremantle              1463 Full Time 11       2012-03-31 16:45:00 105
# 2 Gold Coast             1461 Full Time 23       2012-03-31 15:45:00  68
# 3 Greater Western Sydney 1456 Full Time 16       2012-03-24 19:20:00  37
# 4 Hawthorn               1459 Full Time 19       2012-03-30 19:50:00 137
# 5 Melbourne              1460 Full Time 17       2012-03-31 13:45:00  78
# 6 North Melbourne        1462 Full Time 20       2012-03-31 19:45:00 102

# %%
fixture$venue <- as.factor(fixture$venue)  # convert to factor datatype
summary(fixture$venue)

# check if region has NA values, to see if new/old stadiums in use
check_na_column(fixture, 'region')
# Out:
# Adelaide Arena at Jiangwan Stadium                     Adelaide Hills
#                                  2                                  1
#                      Adelaide Oval                     Bellerive Oval
#                                232                                 36
#                          Blacktown                            Carrara
#                                  1                                157
#                   Cazaly's Stadium                          Docklands
#                                 13                                468
#                     Eureka Stadium                      Football Park
#                                  9                                 46
#                              Gabba                      GMHBA Stadium
#                                162                                 46
#                   Jiangwan Stadium                      Kardinia Park
#                                  1                                 49
#                             M.C.G.                        Manuka Oval
#                                559                                 15
#                       Marrara Oval                       Mars Stadium
#                                 16                                  3
#                     Marvel Stadium                       Norwood Oval
#                                 43                                  2
#                      Optus Stadium                      Perth Stadium
#                                 23                                112
#                   Riverway Stadium                             S.C.G.
#                                  1                                120
#                  Stadium Australia                            Subiaco
#                                 19                                140
#                  Sydney Showground                       Traeger Park
#                                 93                                  9
#     University of Tasmania Stadium                 UNSW Canberra Oval
#                                 24                                 18
#                         Wellington                          York Park
#                                  3                                 24
# [1] 0

# %%
player_stats_23 <- fetch_player_stats(season=2023, round=1)
# Out:
# ℹ Fetching match ids
#
# ✔ Fetching match ids ... done
#
#
#
# ℹ Finding player stats for 9 matches.
#
# ✔ Finding player stats for 9 matches. ... done

# %%
player_stats_23
# Out:
#     providerId      utcStartTime                 status    compSeason.shortName
# 1   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 2   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 3   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 4   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 5   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 6   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 7   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 8   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 9   CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 10  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 11  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 12  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 13  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 14  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 15  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 16  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 17  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 18  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 19  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 20  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 21  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 22  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 23  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 24  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 25  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 26  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 27  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 28  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 29  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# 30  CD_M20230140101 2023-03-16T08:20:00.000+0000 CONCLUDED Premiership
# ⋮   ⋮               ⋮                            ⋮         ⋮
# 385 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 386 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 387 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 388 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 389 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 390 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 391 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 392 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 393 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 394 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 395 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 396 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 397 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 398 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 399 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 400 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 401 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 402 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 403 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 404 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 405 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 406 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 407 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 408 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 409 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 410 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 411 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 412 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 413 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
# 414 CD_M20230140109 2023-03-19T05:40:00.000+0000 CONCLUDED Premiership
#     round.name round.roundNumber venue.name     home.team.name
# 1   Round 1    1                 MCG            Richmond
# 2   Round 1    1                 MCG            Richmond
# 3   Round 1    1                 MCG            Richmond
# 4   Round 1    1                 MCG            Richmond
# 5   Round 1    1                 MCG            Richmond
# 6   Round 1    1                 MCG            Richmond
# 7   Round 1    1                 MCG            Richmond
# 8   Round 1    1                 MCG            Richmond
# 9   Round 1    1                 MCG            Richmond
# 10  Round 1    1                 MCG            Richmond
# 11  Round 1    1                 MCG            Richmond
# 12  Round 1    1                 MCG            Richmond
# 13  Round 1    1                 MCG            Richmond
# 14  Round 1    1                 MCG            Richmond
# 15  Round 1    1                 MCG            Richmond
# 16  Round 1    1                 MCG            Richmond
# 17  Round 1    1                 MCG            Richmond
# 18  Round 1    1                 MCG            Richmond
# 19  Round 1    1                 MCG            Richmond
# 20  Round 1    1                 MCG            Richmond
# 21  Round 1    1                 MCG            Richmond
# 22  Round 1    1                 MCG            Richmond
# 23  Round 1    1                 MCG            Richmond
# 24  Round 1    1                 MCG            Richmond
# 25  Round 1    1                 MCG            Richmond
# 26  Round 1    1                 MCG            Richmond
# 27  Round 1    1                 MCG            Richmond
# 28  Round 1    1                 MCG            Richmond
# 29  Round 1    1                 MCG            Richmond
# 30  Round 1    1                 MCG            Richmond
# ⋮   ⋮          ⋮                 ⋮              ⋮
# 385 Round 1    1                 Marvel Stadium St Kilda
# 386 Round 1    1                 Marvel Stadium St Kilda
# 387 Round 1    1                 Marvel Stadium St Kilda
# 388 Round 1    1                 Marvel Stadium St Kilda
# 389 Round 1    1                 Marvel Stadium St Kilda
# 390 Round 1    1                 Marvel Stadium St Kilda
# 391 Round 1    1                 Marvel Stadium St Kilda
# 392 Round 1    1                 Marvel Stadium St Kilda
# 393 Round 1    1                 Marvel Stadium St Kilda
# 394 Round 1    1                 Marvel Stadium St Kilda
# 395 Round 1    1                 Marvel Stadium St Kilda
# 396 Round 1    1                 Marvel Stadium St Kilda
# 397 Round 1    1                 Marvel Stadium St Kilda
# 398 Round 1    1                 Marvel Stadium St Kilda
# 399 Round 1    1                 Marvel Stadium St Kilda
# 400 Round 1    1                 Marvel Stadium St Kilda
# 401 Round 1    1                 Marvel Stadium St Kilda
# 402 Round 1    1                 Marvel Stadium St Kilda
# 403 Round 1    1                 Marvel Stadium St Kilda
# 404 Round 1    1                 Marvel Stadium St Kilda
# 405 Round 1    1                 Marvel Stadium St Kilda
# 406 Round 1    1                 Marvel Stadium St Kilda
# 407 Round 1    1                 Marvel Stadium St Kilda
# 408 Round 1    1                 Marvel Stadium St Kilda
# 409 Round 1    1                 Marvel Stadium St Kilda
# 410 Round 1    1                 Marvel Stadium St Kilda
# 411 Round 1    1                 Marvel Stadium St Kilda
# 412 Round 1    1                 Marvel Stadium St Kilda
# 413 Round 1    1                 Marvel Stadium St Kilda
# 414 Round 1    1                 Marvel Stadium St Kilda
#     home.team.club.name away.team.name ⋯ extendedStats.centreBounceAttendances
# 1   Richmond            Carlton        ⋯  0
# 2   Richmond            Carlton        ⋯  0
# 3   Richmond            Carlton        ⋯ 11
# 4   Richmond            Carlton        ⋯  0
# 5   Richmond            Carlton        ⋯  6
# 6   Richmond            Carlton        ⋯  0
# 7   Richmond            Carlton        ⋯  0
# 8   Richmond            Carlton        ⋯  0
# 9   Richmond            Carlton        ⋯  0
# 10  Richmond            Carlton        ⋯ 16
# 11  Richmond            Carlton        ⋯  0
# 12  Richmond            Carlton        ⋯ 13
# 13  Richmond            Carlton        ⋯ 18
# 14  Richmond            Carlton        ⋯  0
# 15  Richmond            Carlton        ⋯  0
# 16  Richmond            Carlton        ⋯  0
# 17  Richmond            Carlton        ⋯  0
# 18  Richmond            Carlton        ⋯  0
# 19  Richmond            Carlton        ⋯  0
# 20  Richmond            Carlton        ⋯ 14
# 21  Richmond            Carlton        ⋯  0
# 22  Richmond            Carlton        ⋯  2
# 23  Richmond            Carlton        ⋯  0
# 24  Richmond            Carlton        ⋯  0
# 25  Richmond            Carlton        ⋯  4
# 26  Richmond            Carlton        ⋯  0
# 27  Richmond            Carlton        ⋯ 11
# 28  Richmond            Carlton        ⋯ 14
# 29  Richmond            Carlton        ⋯  0
# 30  Richmond            Carlton        ⋯ 16
# ⋮   ⋮                   ⋮              ⋱ ⋮
# 385 St Kilda            Fremantle      ⋯  0
# 386 St Kilda            Fremantle      ⋯  0
# 387 St Kilda            Fremantle      ⋯  0
# 388 St Kilda            Fremantle      ⋯  0
# 389 St Kilda            Fremantle      ⋯  0
# 390 St Kilda            Fremantle      ⋯  0
# 391 St Kilda            Fremantle      ⋯  0
# 392 St Kilda            Fremantle      ⋯ 15
# 393 St Kilda            Fremantle      ⋯  0
# 394 St Kilda            Fremantle      ⋯  5
# 395 St Kilda            Fremantle      ⋯ 14
# 396 St Kilda            Fremantle      ⋯  0
# 397 St Kilda            Fremantle      ⋯  0
# 398 St Kilda            Fremantle      ⋯  0
# 399 St Kilda            Fremantle      ⋯  0
# 400 St Kilda            Fremantle      ⋯  0
# 401 St Kilda            Fremantle      ⋯ 12
# 402 St Kilda            Fremantle      ⋯  0
# 403 St Kilda            Fremantle      ⋯  0
# 404 St Kilda            Fremantle      ⋯  0
# 405 St Kilda            Fremantle      ⋯ 17
# 406 St Kilda            Fremantle      ⋯  0
# 407 St Kilda            Fremantle      ⋯ 17
# 408 St Kilda            Fremantle      ⋯  0
# 409 St Kilda            Fremantle      ⋯  0
# 410 St Kilda            Fremantle      ⋯  0
# 411 St Kilda            Fremantle      ⋯  0
# 412 St Kilda            Fremantle      ⋯  0
# 413 St Kilda            Fremantle      ⋯  0
# 414 St Kilda            Fremantle      ⋯  0
#     extendedStats.kickins extendedStats.kickinsPlayon player.playerId
# 1   1                     1                           CD_I1000223
# 2   0                     0                           CD_I1002245
# 3   0                     0                           CD_I993993
# 4   0                     0                           CD_I295203
# 5   0                     0                           CD_I270896
# 6   2                     2                           CD_I280819
# 7   0                     0                           CD_I293813
# 8   0                     0                           CD_I1008478
# 9   0                     0                           CD_I993771
# 10  0                     0                           CD_I998172
# 11  1                     1                           CD_I294674
# 12  0                     0                           CD_I993903
# 13  0                     0                           CD_I298174
# 14  0                     0                           CD_I1009551
# 15  0                     0                           CD_I990827
# 16  1                     1                           CD_I992049
# 17  0                     0                           CD_I294592
# 18  0                     0                           CD_I250395
# 19  4                     3                           CD_I1000981
# 20  0                     0                           CD_I290627
# 21  0                     0                           CD_I290847
# 22  0                     0                           CD_I1002403
# 23  0                     0                           CD_I1006133
# 24  0                     0                           CD_I1021353
# 25  0                     0                           CD_I270146
# 26  0                     0                           CD_I296294
# 27  0                     0                           CD_I1002239
# 28  0                     0                           CD_I990704
# 29  0                     0                           CD_I996731
# 30  0                     0                           CD_I1004912
# ⋮   ⋮                     ⋮                           ⋮
# 385 0                     0                           CD_I993480
# 386 0                     0                           CD_I1023272
# 387 0                     0                           CD_I1004985
# 388 4                     4                           CD_I994389
# 389 5                     2                           CD_I1015507
# 390 0                     0                           CD_I295584
# 391 0                     0                           CD_I290757
# 392 0                     0                           CD_I1009420
# 393 0                     0                           CD_I996580
# 394 0                     0                           CD_I1009399
# 395 0                     0                           CD_I294613
# 396 2                     1                           CD_I998659
# 397 0                     0                           CD_I1000860
# 398 0                     0                           CD_I992059
# 399 0                     0                           CD_I298409
# 400 0                     0                           CD_I998180
# 401 0                     0                           CD_I998129
# 402 0                     0                           CD_I1005988
# 403 1                     1                           CD_I997033
# 404 0                     0                           CD_I999321
# 405 0                     0                           CD_I998145
# 406 0                     0                           CD_I295067
# 407 0                     0                           CD_I1002232
# 408 0                     0                           CD_I291570
# 409 2                     1                           CD_I1009256
# 410 0                     0                           CD_I1013224
# 411 0                     0                           CD_I1006152
# 412 0                     0                           CD_I293854
# 413 0                     0                           CD_I1012819
# 414 2                     1                           CD_I294125
#     player.captain player.playerJumperNumber player.givenName player.surname
# 1   FALSE           7                        Liam             Baker
# 2   FALSE          21                        Noah             Balta
# 3   FALSE          29                        Shai             Bolton
# 4   FALSE          35                        Nathan           Broad
# 5   FALSE           9                        Trent            Cotchin
# 6   FALSE           2                        Dylan            Grimes
# 7   FALSE          19                        Tom              Lynch
# 8   FALSE          31                        Rhyan            Mansell
# 9   FALSE          50                        Marlion          Pickett
# 10  FALSE          14                        Tim              Taranto
# 11  FALSE           1                        Nick             Vlastuin
# 12  FALSE          22                        Jacob            Hopper
# 13  FALSE          25                        Toby             Nankervis
# 14  FALSE          10                        Maurice          Rioli
# 15  FALSE          34                        Jack             Graham
# 16  FALSE          15                        Jayden           Short
# 17  FALSE          33                        Kamdyn           McIntosh
# 18  FALSE           8                        Jack             Riewoldt
# 19  FALSE          17                        Daniel           Rioli
# 20  FALSE           3                        Dion             Prestia
# 21  FALSE           4                        Dustin           Martin
# 22  FALSE          46                        Ben              Miller
# 23  FALSE           5                        Jack             Ross
# 24  FALSE          26                        Lachlan          Cowan
# 25  FALSE          35                        Ed               Curnow
# 26  FALSE          13                        Blake            Acres
# 27  FALSE           5                        Adam             Cerra
# 28  FALSE           9                        Patrick          Cripps
# 29  FALSE          30                        Charlie          Curnow
# 30  FALSE          12                        Tom              De Koning
# ⋮   ⋮              ⋮                         ⋮                ⋮
# 385 FALSE          20                        Dougal           Howard
# 386 FALSE          10                        Mitch            Owens
# 387 FALSE          33                        Ben              Paton
# 388 FALSE          35                        Jack             Sinclair
# 389 FALSE           7                        Nasiah           Wanganeen-Milera
# 390 FALSE           8                        Bradley          Hill
# 391 FALSE          29                        Jimmy            Webster
# 392 FALSE           3                        Caleb            Serong
# 393 FALSE          15                        Ethan            Hughes
# 394 FALSE           9                        Luke             Jackson
# 395 FALSE           2                        Jaeger           O'Meara
# 396 FALSE          13                        Luke             Ryan
# 397 FALSE           5                        Lachie           Schultz
# 398 FALSE          39                        Sam              Switkowski
# 399 FALSE          25                        Alex             Pearce
# 400 FALSE          41                        Bailey           Banfield
# 401 FALSE          17                        Will             Brodie
# 402 FALSE          23                        Liam             Henry
# 403 FALSE          36                        Brennan          Cox
# 404 FALSE          32                        Michael          Frederick
# 405 FALSE           4                        Sean             Darcy
# 406 FALSE          11                        James            Aish
# 407 FALSE           8                        Andrew           Brayshaw
# 408 FALSE           7                        Nat              Fyfe
# 409 FALSE          26                        Hayden           Young
# 410 FALSE          27                        Heath            Chapman
# 411 FALSE           6                        Jordan           Clark
# 412 FALSE          20                        Matt             Taberner
# 413 FALSE          35                        Josh             Treacy
# 414 FALSE          14                        Nathan           Wilson
#     teamStatus team.name
# 1   home       Richmond
# 2   home       Richmond
# 3   home       Richmond
# 4   home       Richmond
# 5   home       Richmond
# 6   home       Richmond
# 7   home       Richmond
# 8   home       Richmond
# 9   home       Richmond
# 10  home       Richmond
# 11  home       Richmond
# 12  home       Richmond
# 13  home       Richmond
# 14  home       Richmond
# 15  home       Richmond
# 16  home       Richmond
# 17  home       Richmond
# 18  home       Richmond
# 19  home       Richmond
# 20  home       Richmond
# 21  home       Richmond
# 22  home       Richmond
# 23  home       Richmond
# 24  away       Carlton
# 25  away       Carlton
# 26  away       Carlton
# 27  away       Carlton
# 28  away       Carlton
# 29  away       Carlton
# 30  away       Carlton
# ⋮   ⋮          ⋮
# 385 home       St Kilda
# 386 home       St Kilda
# 387 home       St Kilda
# 388 home       St Kilda
# 389 home       St Kilda
# 390 home       St Kilda
# 391 home       St Kilda
# 392 away       Fremantle
# 393 away       Fremantle
# 394 away       Fremantle
# 395 away       Fremantle
# 396 away       Fremantle
# 397 away       Fremantle
# 398 away       Fremantle
# 399 away       Fremantle
# 400 away       Fremantle
# 401 away       Fremantle
# 402 away       Fremantle
# 403 away       Fremantle
# 404 away       Fremantle
# 405 away       Fremantle
# 406 away       Fremantle
# 407 away       Fremantle
# 408 away       Fremantle
# 409 away       Fremantle
# 410 away       Fremantle
# 411 away       Fremantle
# 412 away       Fremantle
# 413 away       Fremantle
# 414 away       Fremantle

# %%
player_details <- fetch_player_details(season = 2022, source = "afltables")
# Out:
# → For the afltables source, details are returned for all seasons. Ignoring `current` argument
#
# ℹ Fetching player details for all teams
#
# ℹ Fetching player details for Adelaide
#
# ✔ Fetching player details for Adelaide ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Brisbane Lions
#
# ✔ Fetching player details for Brisbane Lions ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Brisbane Bears
#
# ✔ Fetching player details for Brisbane Bears ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Carlton
#
# ✔ Fetching player details for Carlton ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Collingwood
#
# ✔ Fetching player details for Collingwood ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Essendon
#
# ✔ Fetching player details for Essendon ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Fitzroy
#
# ✔ Fetching player details for Fitzroy ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Fremantle
#
# ✔ Fetching player details for Fremantle ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for GWS
#
# ✔ Fetching player details for GWS ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Geelong
#
# ✔ Fetching player details for Geelong ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Gold Coast
#
# ✔ Fetching player details for Gold Coast ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Hawthorn
#
# ✔ Fetching player details for Hawthorn ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Melbourne
#
# ✔ Fetching player details for Melbourne ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for North Melbourne
#
# ✔ Fetching player details for North Melbourne ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Port Adelaide
#
# ✔ Fetching player details for Port Adelaide ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Richmond
#
# ✔ Fetching player details for Richmond ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for St Kilda
#
# ✔ Fetching player details for St Kilda ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Sydney
#
# ✔ Fetching player details for Sydney ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for West Coast
#
# ✔ Fetching player details for West Coast ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for University
#
# ✔ Fetching player details for University ... done
#
#
#
# ℹ Fetching player details for all teams
# ℹ Fetching player details for Western Bulldogs
#
# ✔ Fetching player details for Western Bulldogs ... done
#
#
#
# ℹ Fetching player details for all teams
# ✔ Fetching player details for all teams ... done

# %%
player_details_22
# Out:
# Error in eval(expr, envir, enclos): object 'player_details_22' not found
# Traceback:

# %%
player_details_22

# %%
freo_details_23

# %%
colnames(player_stats_23)

# %%
player_stats_22

# %% [markdown]
# # CSV Output
# Write to a csv for further python analysis

# %%
write.csv(fixture, file='fixture.csv', row.names=FALSE)
